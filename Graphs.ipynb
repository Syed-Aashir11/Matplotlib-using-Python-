# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
weather = pd.read_csv("https://raw.githubusercontent.com/alanjones2/dataviz/master/london2018.csv")
weather
# Out:
#     Year  Month  Tmax  Tmin  Rain    Sun
# 0   2018      1   9.7   3.8  58.0   46.5
# 1   2018      2   6.7   0.6  29.0   92.0
# 2   2018      3   9.8   3.0  81.2   70.3
# 3   2018      4  15.5   7.9  65.2  113.4
# 4   2018      5  20.8   9.8  58.4  248.3
# 5   2018      6  24.2  13.1   0.4  234.5
# 6   2018      7  28.3  16.4  14.8  272.5
# 7   2018      8  24.5  14.5  48.2  182.1
# 8   2018      9  20.9  11.0  29.4  195.0
# 9   2018     10  16.5   8.5  61.0  137.0
# 10  2018     11  12.2   5.8  73.8   72.9
# 11  2018     12  10.7   5.2  60.6   40.3

# %%
weather.plot(y= "Tmax", x= "Tmin")
# Out:
# <AxesSubplot:xlabel='Tmin'>

# %%
weather.plot(y= "Tmin", x= "Rain")
# Out:
# <AxesSubplot:xlabel='Rain'>

# %%
weather.plot(x= "Year", y= "Sun")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
weather.plot(y= "Rain", x= "Sun")
# Out:
# <AxesSubplot:xlabel='Sun'>

# %%
weather.plot(x= "Tmax", y= "Tmin")
# Out:
# <AxesSubplot:xlabel='Tmax'>

# %%
weather.plot(y= "Tmax", x= "Rain")
# Out:
# <AxesSubplot:xlabel='Rain'>

# %%
weather.plot(y= "Sun", x= "Tmin")
# Out:
# <AxesSubplot:xlabel='Tmin'>

# %%
weather.plot(y= "Rain", x= "Tmin")
# Out:
# <AxesSubplot:xlabel='Tmin'>

# %%
weather.plot(y= ["Tmax","Tmin"], x= "Month")
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
weather.plot(y= ["Tmax","Tmin"], x= "Rain")
# Out:
# <AxesSubplot:xlabel='Rain'>

# %%
weather.plot(y= ["Tmax","Tmin"], x= "Sun")
# Out:
# <AxesSubplot:xlabel='Sun'>

# %%
weather.plot(y= ["Tmax","Tmin"], x= "Year")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
weather.plot(y= ["Tmax","Rain"], x= "Tmin")
# Out:
# <AxesSubplot:xlabel='Tmin'>

# %%
weather.plot(y= ["Tmax","Sun"], x= "Tmin")
# Out:
# <AxesSubplot:xlabel='Tmin'>

# %%
weather.plot(y= ["Rain","Sun"], x= "Month")
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
weather.plot(y= ["Rain","Sun"], x= "Tmin")
# Out:
# <AxesSubplot:xlabel='Tmin'>

# %%
weather.plot(y= ["Month","Tmax"], x= "Tmin")
# Out:
# <AxesSubplot:xlabel='Tmin'>

# %%
weather.plot(y= ["Sun","Tmax"], x= "Month")
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
weather.plot(y= ["Tmin","Rain"], x= "Month")
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
weather.plot.bar(y= ["Tmax","Tmin"], x= "Month")
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
weather.plot.barh(y= ["Tmax","Tmin"], x= "Month")
# Out:
# <AxesSubplot:ylabel='Month'>

# %%
weather.plot.bar(y="Tmax", x= "Month")
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
weather.plot.barh(y="Tmax", x= "Month")
# Out:
# <AxesSubplot:ylabel='Month'>

# %%
weather.plot.scatter(y='Rain', x='Month')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Rain'>

# %%
weather.plot.scatter(y='Sun', x='Month')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Sun'>

# %%
weather.plot.scatter(y='Sun', x='Tmax')
# Out:
# <AxesSubplot:xlabel='Tmax', ylabel='Sun'>

# %%
weather.plot.scatter(y='Rain', x='Tmax')
# Out:
# <AxesSubplot:xlabel='Tmax', ylabel='Rain'>

# %%
weather.plot.scatter(y='Tmin', x='Tmax')
# Out:
# <AxesSubplot:xlabel='Tmax', ylabel='Tmin'>

# %%
weather.plot.scatter(y='Sun', x='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Sun'>

# %%
weather.plot.scatter(y='Sun', x='Rain')
# Out:
# <AxesSubplot:xlabel='Rain', ylabel='Sun'>

# %%
weather.plot.scatter(y='Rain', x='Sun')
# Out:
# <AxesSubplot:xlabel='Sun', ylabel='Rain'>

# %%
weather.plot.scatter(y='Rain', x='Tmax')
# Out:
# <AxesSubplot:xlabel='Tmax', ylabel='Rain'>

# %%
weather.plot.barh(y= ['Year','Sun'], x= 'Rain')
# Out:
# <AxesSubplot:ylabel='Rain'>

# %%
weather.plot.barh(y= ['Year','Sun'], x= 'Rain')
